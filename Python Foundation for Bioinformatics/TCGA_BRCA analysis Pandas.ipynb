# %%
import pandas as pd
df=pd.read_csv("/content/sample_data/california_housing_train.csv")
#display the first 5 rows of the table to verify
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
import pandas as pd
df_brca=pd.read_csv("/content/brca.csv.zip", encoding='latin1', on_bad_lines='skip', engine='python')
print(f"total rows:{df_brca.shape[0]}, total column:{df_brca.shape[1]}")
df_brca.head()
# Out:
# total rows:705, total column:1937
#    rs_CLEC3A    rs_CPB1  rs_SCGB2A2  rs_SCGB1D2    rs_TFF1   rs_MUCL1  \
# 0   0.892818   6.580103   14.123672   10.606501  13.189237   6.649466
# 1   0.000000   3.691311   17.116090   15.517231   9.867616   9.691667
# 2   3.748150   4.375255    9.658123    5.326983  12.109539  11.644307
# 3   0.000000  18.235519   18.535480   14.533584  14.078992   8.913760
# 4   0.000000   4.583724   15.711865   12.804521   8.881669   8.430028
#
#     rs_GSTM1     rs_PIP  rs_ADIPOQ   rs_ADH1B  ...  pp_p27.pT198  pp_p38.MAPK  \
# 0  10.520335  10.338490  10.248379  10.229970  ...     -0.043330    -0.002598
# 1   8.179522   7.911723   1.289598   1.818891  ...     -0.220764     0.220809
# 2  10.517330   5.114925  11.975349  11.911437  ...      0.010615    -0.133214
# 3  10.557465  13.304434   8.205059   9.211476  ...      0.064070    -0.384008
# 4  12.964607   6.806517   4.294341   5.385714  ...     -0.065488     0.209858
#
# ...

# %%
import numpy as np
avg=np.mean(df_brca['rs_CLEC3A'])
print(f'Average: {avg}')
# Out:
# Average: 4.5471968163390155

# %%
import numpy as np
all_mean = df_brca.mean(numeric_only=True)
print(all_mean.head())
# Out:
# rs_CLEC3A     4.547197
# rs_CPB1       6.487979
# rs_SCGB2A2    9.516678
# rs_SCGB1D2    7.351940
# rs_TFF1       8.179439
# dtype: float64

# %%
import numpy as np
sample_array=df_brca['rs_CLEC3A']
reshaped_data = sample_array.to_numpy().reshape(-1,1)
print("reshaped data:", reshaped_data)
# Out:
# reshaped data: [[ 0.89281843]
#  [ 0.        ]
#  [ 3.7481499 ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.60283691]
#  [ 5.65431237]
#  [ 2.37094541]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [12.08081283]
#  [ 0.54744983]
#  [10.22000219]
#  [ 0.        ]
#  [ 1.22502808]
#  [ 0.        ]
#  [ 5.2076274 ]
#  [ 0.        ]
#  [ 4.3764571 ]
#  [ 5.27236291]
#  [12.67569735]
#  [ 0.        ]
#  [ 0.        ]
#  [ 1.68602982]
#  [ 4.72636804]
#  [ 5.39238612]
#  [ 3.76062548]
#  [11.20323334]
#  [ 7.25464884]
#  [ 0.        ]
#  [ 3.30977282]
#  [ 5.7718803 ]
#  [11.71497604]
#  [10.41783722]
#  [ 0.        ]
#  [ 0.        ]
#  [ 5.17298748]
#  [ 0.        ]
#  [13.50333239]
#  [ 7.5638735 ]
#  [ 1.69950721]
#  [ 0.        ]
#  [ 1.52240734]
#  [ 2.19115202]
#  [ 4.05538657]
#  [10.83083223]
#  [ 2.32538641]
#  [ 0.38106183]
#  [10.2537331 ]
#  [15.89298525]
#  [ 0.97548345]
#  [ 0.3971458 ]
#  [ 0.33993549]
#  [12.95598998]
#  [ 4.87683124]
# ...
